# %% [markdown]
# # MI PRIMER PROGRAMA
# ## FREDDY GUEVARA
# ### INTRODUCCION A PROGRAMACION CON PAYTHON

# %%
#Escribir primer Hola Mundo
print("HOLA MUNDO")
# Out:
# HOLA MUNDO

# %% [markdown]
# # CLASES 2
# ## Sintaxis Basicas

# %%
"""
Nombre: Freddy Guevara
Programa del algoritmo 

"""

#Define una variable llamada estudiante
estudiante="Freddy"
#Imprime un Hola mas la variable estudiante
print ("Hola",estudiante)
#Salto de Linea \alt 92 + n
print ("Hola, \nestimado estudiante\n")
#Tabulacion \t
print ("Menu: \tHamburguesa")
#Espacios Literale - -
# Out:
# Hola Freddy
# Hola,
# estimado estudiante
