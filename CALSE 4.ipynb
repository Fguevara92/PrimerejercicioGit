# %%
cantidad=5
precio=30.50
nombre_producto= "Laptop"
existe_productos=True

print("El producto en venta", nombre_producto, "tiene un precio de", precio, "y tenemos en existencia", cantidad, existe_productos)
# Out:
# El producto en venta Laptop tiene un precio de 30.5 y tenemos en existencia 5 True

# %%
nombre_estudiante="Freddy"
edad=34
esta_aprobado=True
nota_final=8.00

# %% [markdown]
# # Tarea 4

# %%
# Estado Inicial del Sistema
plato_1="Pollo Asado"
plato_2="Chuleta Asada"
plato_3=plato_1
plato_1=plato_2
plato_2=plato_3

#=================================
# ESCRIBE TU LOGICA DE INTERCAMBIO AQUI ABAJO

print("El plato 1 ahora es:", plato_1)
print("El plato 2 ahora es:", plato_2)
# Out:
# El plato 1 ahora es: Chuleta Asada
# El plato 2 ahora es: Pollo Asado
