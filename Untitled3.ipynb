# %% [markdown]
# # Clase 5

# %%
#operadores aritmetico

numero_1=5
numero_2=8

# %%
#operadores especiales
#division entera
numero_1=8
numero_2=2

div_esp = numero_1 // numero_2

#Exponente
exp = numero_2 ** 4

#modulo o residuo
mod = numero_1 % 2

#raiz


print("El resultado de la division especial es:", div_esp)
print("El resultado del exponente es:", exp)
print("El resultado del modulo (residuo) es:", mod)
# Out:
# El resultado de la division especial es: 4
# El resultado del exponente es: 16
# El resultado del modulo (residuo) es: 0

# %%
#orde jerarquia
#mal resultado
print(10+2*5**2)

#bien
print((10+2)*5**2)
# Out:
# 60
# 300

# %%
#ejercicio

a=2
b=-7
c=3

raiz= -b**2
int_raiz= raiz
div_ba=2*a



print((-b - int_raiz) / div_ba)
# Out:
# 14.0
