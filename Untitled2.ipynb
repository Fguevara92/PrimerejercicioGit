# %% [markdown]
# # TAREA 2

# %%
print ("    r**** ")
print ("    ^")
print ("   / \        ___")
print ("  / o \      | o |")
print (" /_____\     |   |")
print ("|  ___  |    | o |")
print ("| |   | |    |   |")
print ("|_|_|_|_|____|_|_|")
print ("|                |")
print ("|    <3      <3  |")
print ("|________________|")
# Out:
#     r****
#     ^
#    / \        ___
#   / o \      | o |
#  /_____\     |   |
# |  ___  |    | o |
# | |   | |    |   |
# |_|_|_|_|____|_|_|
# |                |
# |    <3      <3  |
# |________________|
