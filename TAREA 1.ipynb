# %% [markdown]
# #TAREA

# %%
"""
Nombre: Freddy Guevara
Programa del algoritmo que tienen, en un dia desde levantarse hasta acostarse

"""

print ("01. Levantarme de la cama")
print ("02. Tender la cama")
print ("03. Aseo personal")
print ("04. Cambiarse con la ropa de trabajo")
print ("05. Preparar un desayuno sencillo y rápido que no tome mucho tiempo.")
print ("06. Desayunar en un lapso máximo de 20 minutos para mantener el cronograma bajo control.")
print ("07. Verificar el apagado de luces, electrodomésticos de la cocina y el cierre correcto de las cerraduras principales antes de salir.")
print ("08. Revisar el nivel del tanque el día anterior para no tener que hacer paradas imprevistas en la gasolinera durante el expreso.")
print ("09. Verificar la presión de las llantas y fluidos básicos como aceite del motor, refrigerante y frenos para mitigar riesgos de averías en la vía.")
print ("10. Consultar aplicaciones de navegación justo antes de encender el auto para identificar bloqueos o rutas alternas.")
print ("11. Asegurar que la hora del vehículo y del dispositivo móvil estén alineadas con el horario oficial de la empresa.")
# Out:
# 01. Levantarme de la cama
# 02. Tender la cama
# 03. Aseo personal
# 04. Cambiarse con la ropa de trabajo
# 05. Preparar un desayuno sencillo y rápido que no tome mucho tiempo.
# 06. Desayunar en un lapso máximo de 20 minutos para mantener el cronograma bajo control.
# 07. Verificar el apagado de luces, electrodomésticos de la cocina y el cierre correcto de las cerraduras principales antes de salir.
# 08. Revisar el nivel del tanque el día anterior para no tener que hacer paradas imprevistas en la gasolinera durante el expreso.
# 09. Verificar la presión de las llantas y fluidos básicos como aceite del motor, refrigerante y frenos para mitigar riesgos de averías en la vía.
# 10. Consultar aplicaciones de navegación justo antes de encender el auto para identificar bloqueos o rutas alternas.
# 11. Asegurar que la hora del vehículo y del dispositivo móvil estén alineadas con el horario oficial de la empresa.

# %%
"""
Nombre: Freddy Guevara
Programa del algoritmo que tienen, en un dia desde levantarse hasta acostarse

"""

print("1. Sonar alarma a las 06:00 a.m.")
print("2. Tomar ducha rápida.")
print("3. Cepillarse los dientes.") 
print("4. Ponerse la ropa de trabajo.")
print("5. Preparar desayuno rápido.")
print("6. Desayunar en máximo 20 minutos.")
print("7. Apagar luces y asegurar la casa.")
print("8. Revisar nivel de combustible.") 
print("9. Chequear llantas y fluidos del auto.") 
print("10. Revisar GPS para evitar tráfico.") 
print("11. Sincronizar reloj con la empresa.") 
print("12. Seguir ruta por proximidad geográfica.") 
print("13. Esperar máximo 3 minutos por pasajero.") 
print("14. Avisar llegada por chat.") 
print("15. Asegurar espacio cómodo en el vehículo.") 
print("16. Exigir cinturones de seguridad.") 
print("17. Conducir a velocidad prudente y constante.")
print("18. Llegar a la oficina a las 07:55 a.m.")
print("19. Estacionar en espacio de salida rápida.")
print("20. Marcar entrada al trabajo a las 08:00 a.m.")
print("21. Realizar las tareas laborales del día.")
print("22. Esperar la hora de salida y marcar a las 05:00 p.m.")
print("23. Realizar ruta de regreso para dejar a los pasajeros del expreso.")
print("24. Ingresar a clases a las 06:30 p.m.")
print("25. Finalizar clases a las 09:30 p.m.")
print("26. Realizar tareas académicas hasta las 11:00 p.m.")
print("27. Tomar un baño.")
print("28. Arreglar la cama.")
print("29. Dormir.")
# Out:
# 1. Sonar alarma a las 06:00 a.m.
# 2. Tomar ducha rápida.
# 3. Cepillarse los dientes.
# 4. Ponerse la ropa de trabajo.
# 5. Preparar desayuno rápido.
# 6. Desayunar en máximo 20 minutos.
# 7. Apagar luces y asegurar la casa.
# 8. Revisar nivel de combustible.
# 9. Chequear llantas y fluidos del auto.
# 10. Revisar GPS para evitar tráfico.
# 11. Sincronizar reloj con la empresa.
# 12. Seguir ruta por proximidad geográfica.
# 13. Esperar máximo 3 minutos por pasajero.
# 14. Avisar llegada por chat.
# 15. Asegurar espacio cómodo en el vehículo.
# 16. Exigir cinturones de seguridad.
# 17. Conducir a velocidad prudente y constante.
# 18. Llegar a la oficina a las 07:55 a.m.
# 19. Estacionar en espacio de salida rápida.
# 20. Marcar entrada al trabajo a las 08:00 a.m.
# 21. Realizar las tareas laborales del día.
# 22. Esperar la hora de salida y marcar a las 05:00 p.m.
# 23. Realizar ruta de regreso para dejar a los pasajeros del expreso.
# 24. Ingresar a clases a las 06:30 p.m.
# ...

# %%
#DIBUJAR UNA FIGURA EN PYTHON CON CODIGO ASCII


print("   .-----------------. ")
print("   |                 | ")
print("   |  >_ EN LINEA    | ")
print("   |                 | ")
print("   '-----------------' ")
print("      =============    ")
print("    /~~~~~~~~~~~~~~~\\\\ ")
print("  /___________________\\\\")
# Out:
#    .-----------------.
#    |                 |
#    |  >_ EN LINEA    |
#    |                 |
#    '-----------------'
# ...
#     /~~~~~~~~~~~~~~~\\
#   /___________________\\
